# %%
import matplotlib.pyplot as plt
import numpy as np
from pz_data_challenge import evaluation

# %%
RESULTS_DIR = '../results'
SUBMISSIONS = evaluation.get_submissions()

# %%
data_dict = evaluation.build_summary_data_dict(RESULTS_DIR, SUBMISSIONS, "timing")

# %%
fig_algo_estimate_time = evaluation.make_algo_estimate_time_strip_plot(
    data_dict,
    SUBMISSIONS,
)

# %%
fig_algo_inform_time = evaluation.make_algo_inform_time_strip_plot(
    data_dict,
    SUBMISSIONS,
)

# %%
fig_algo_estimate_time.savefig(f"{RESULTS_DIR}/summary_timing_estimate.png")

# %%
fig_algo_inform_time.savefig(f"{RESULTS_DIR}/summary_timing_inform.png")
