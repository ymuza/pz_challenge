# %%
import yaml
import matplotlib.pyplot as plt
import numpy as np
from pz_data_challenge import evaluation, scoring

# %%
RESULTS_DIR = '../results'
SUBMISSIONS = evaluation.get_submissions()

# %%
data_dict = evaluation.build_summary_data_dict(RESULTS_DIR, SUBMISSIONS, "point_v_mag")

# %%
fig_point_v_redshift = evaluation.make_point_v_mag_plot(
    data_dict, 
    SUBMISSIONS, 
    r"Mean $\frac{z_{\rm est} - z_{\rm ref}}{1 + z_{\rm ref}}$",
    'biweight_mean', 
    [-1, 1],
    scoring.metric_dict['mean'],
)

# %%
data_dict['easy_forest']['z_mean']
