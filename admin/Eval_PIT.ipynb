# %%
import matplotlib.pyplot as plt
import numpy as np
from pz_data_challenge import evaluation

# %%
RESULTS_DIR = '../results'
SUBMISSIONS = evaluation.get_submissions()

# %%
data_dict = evaluation.build_summary_data_dict(RESULTS_DIR, SUBMISSIONS, "pit_prob")

# %%
fig_qq_plot = evaluation.make_qq_pit_plot(data_dict, SUBMISSIONS)

# %%
fig_qq_plot.savefig(f"{RESULTS_DIR}/summary_pit_qq_plot.png")
